# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip install -U sentence-transformers
# Out:
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.1.0.tar.gz (78 kB)
#      |████████████████████████████████| 78 kB 4.2 MB/s
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.12.3-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 17.5 MB/s
# Collecting tokenizers>=0.10.3
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 45.3 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (4.62.3)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.10.0+cu111)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (0.11.1+cu111)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.19.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (0.22.2.post1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.4.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (3.2.5)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 72.5 MB/s
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.1.2-py3-none-any.whl (59 kB)
#      |████████████████████████████████| 59 kB 6.7 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.6.0->sentence-transformers) (3.10.0.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (4.8.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2019.12.20)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (3.3.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2.23.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (21.2)
# Collecting sacremoses
#   Downloading sacremoses-0.0.46-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 60.0 MB/s
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 56.0 MB/s
# Requirement already satisfied: pyparsing<3,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers<5.0.0,>=4.6.0->sentence-transformers) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers<5.0.0,>=4.6.0->sentence-transformers) (3.6.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk->sentence-transformers) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (3.0.4)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<5.0.0,>=4.6.0->sentence-transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<5.0.0,>=4.6.0->sentence-transformers) (1.1.0)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence-transformers) (7.1.2)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.1.0-py3-none-any.whl size=121000 sha256=151fd49fd843289a8ce1bfaa6a90fb6adc69b8998e5628653813b8161a3ac223
#   Stored in directory: /root/.cache/pip/wheels/90/f0/bb/ed1add84da70092ea526466eadc2bfb197c4bcb8d4fa5f7bad
# Successfully built sentence-transformers
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers, sentencepiece, sentence-transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.1.2 pyyaml-6.0 sacremoses-0.0.46 sentence-transformers-2.1.0 sentencepiece-0.1.96 tokenizers-0.10.3 transformers-4.12.3

# %%
#Dataset preparation
import json
import pandas as pd

path = '/content/drive/MyDrive/ALDA_project/Training_dataset/'
testing_path = '/content/drive/MyDrive/ALDA_project/test_set/'

#Load the training dataset using metadata and label data.
train_df = pd.read_csv(path + 'devset_images_gt.csv')
train_df.columns=(['image_id', 'label'])
train_df["image_id"] = train_df["image_id"].astype(str)
train_df = train_df[train_df.columns[[0, 1]]]

json_filename = path + "devset_images_metadata.json"
with open(json_filename) as json_file:
    data = json.load(json_file)

required_columns = ['description', 'user_tags', 'image_id', 'title']
json_df = pd.DataFrame(data['images'], columns = required_columns)
print(json_df.head())
#merge label and json dataframes
train_df = pd.merge(train_df, json_df, how='inner')
train_df.head()


#Load the testing dataset using metadata and label data.
test_df = pd.read_csv(testing_path + 'testset_images_gt.csv')
test_df.columns=(['image_id', 'label'])
test_df["image_id"] = test_df["image_id"].astype(str)
test_df = test_df[test_df.columns[[0, 1]]]

json_filename = testing_path + "testset_images_metadata.json"
with open(json_filename) as json_file:
    data = json.load(json_file)

required_columns = ['description', 'user_tags', 'image_id', 'title']
json_df = pd.DataFrame(data['images'], columns = required_columns)
#merge label and json dataframes
test_df = pd.merge(test_df, json_df, how='inner')
test_df.head()
# Out:
#                                          description  ...                   title
# 0                                               None  ...         Biltmore Estate
# 1                                               None  ...             Chand Minar
# 2  After the flood, the boarded up stores bear up...  ...      Uplifting Graffiti
# 3                                               None  ...                DSCF6487
# 4                                               None  ...  Oconoe river - flooded
#
# [5 rows x 4 columns]
#      image_id  ...                                title
# 0   347783223  ...                       Killing fields
# 1  6310531921  ...  Cambodia - flooded path to temple 2
# 2  8329435841  ...                       War Eagle Mill
# 3  3330434964  ...                        20090131_7286
# 4  2862785695  ...                             building
#
# [5 rows x 5 columns]

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('bert-base-nli-mean-tokens')
# Out:
# Downloading:   0%|          | 0.00/391 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.95k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/625 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/399 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
train_df = train_df.drop(columns=['user_tags','image_id'])
test_df = test_df.drop(columns=['user_tags','image_id'])
train_df = train_df.fillna(" ")
test_df = test_df.fillna(" ")

# %%
X_train = train_df[['description', 'title']]
y_train = train_df['label'].tolist()
X_test = test_df[['description', 'title']]
y_test = test_df['label'].tolist()

# %%
#Generating the embeddings for description and title
sentence_embeddings_description_train = model.encode(X_train.loc[:,'description'].tolist())
sentence_embeddings_title_train = model.encode(X_train.loc[:,'title'].tolist())

# %%
sentence_embeddings_description_test = model.encode(X_test.loc[:,'description'].to_list())
sentence_embeddings_title_test = model.encode(X_test.loc[:,'title'].to_list())

# %%
#Concatenating the embeddings
X_train = []
for i in range(len(sentence_embeddings_description_train)):
  X_train.append(sentence_embeddings_description_train[i].tolist() + sentence_embeddings_title_train[i].tolist())
X_test = []
for i in range(len(sentence_embeddings_description_test)):
  X_test.append(sentence_embeddings_description_test[i].tolist() + sentence_embeddings_title_test[i].tolist())

# %%
#Model building and training
from sklearn.svm import SVC
svm = SVC(kernel='rbf')

svm.fit(X_train, y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
#Test set evaluation metrics
from sklearn.metrics import classification_report

#predict response using SVM
svm_y_pred = svm.predict(X_test)

# calculate report for svm model
svm_report = classification_report(y_test, svm_y_pred, target_names=['not flooded', 'flooded'])

print('SVM Model classification report is: \n', svm_report)
# Out:
# SVM Model classification report is:
#                precision    recall  f1-score   support
#
#  not flooded       0.80      0.77      0.78       839
#      flooded       0.62      0.65      0.64       480
#
#     accuracy                           0.73      1319
#    macro avg       0.71      0.71      0.71      1319
# weighted avg       0.73      0.73      0.73      1319

# %%
#Fine tuning the model using GridSearch
from sklearn.model_selection import GridSearchCV
 
# defining parameter range
param_grid = {'C': [0.1, 1, 10, 100, 1000],
              'gamma': [2, 1, 0.1, 0.01, 0.001, 0.0001],
              'kernel': ['rbf', 'linear']}
 
svm_grid = GridSearchCV(SVC(), param_grid, refit = True, verbose = 3)
 
# fitting the model for grid search
svm_grid.fit(X_train, y_train)

# print how our model looks after hyper-parameter tuning
print(svm_grid.best_estimator_)
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# [CV] C=0.1, gamma=2, kernel=rbf ......................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] .......... C=0.1, gamma=2, kernel=rbf, score=0.636, total=  57.4s
# [CV] C=0.1, gamma=2, kernel=rbf ......................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   57.4s remaining:    0.0s
# [CV] .......... C=0.1, gamma=2, kernel=rbf, score=0.636, total=  57.8s
# [CV] C=0.1, gamma=2, kernel=rbf ......................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  1.9min remaining:    0.0s
# [CV] .......... C=0.1, gamma=2, kernel=rbf, score=0.636, total=  57.1s
# [CV] C=0.1, gamma=2, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=2, kernel=rbf, score=0.636, total=  57.7s
# [CV] C=0.1, gamma=2, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=2, kernel=rbf, score=0.636, total=  57.3s
# [CV] C=0.1, gamma=2, kernel=linear ...................................
# [CV] ....... C=0.1, gamma=2, kernel=linear, score=0.761, total=  36.4s
# [CV] C=0.1, gamma=2, kernel=linear ...................................
# [CV] ....... C=0.1, gamma=2, kernel=linear, score=0.748, total=  35.6s
# [CV] C=0.1, gamma=2, kernel=linear ...................................
# [CV] ....... C=0.1, gamma=2, kernel=linear, score=0.752, total=  35.1s
# [CV] C=0.1, gamma=2, kernel=linear ...................................
# [CV] ....... C=0.1, gamma=2, kernel=linear, score=0.756, total=  36.4s
# [CV] C=0.1, gamma=2, kernel=linear ...................................
# [CV] ....... C=0.1, gamma=2, kernel=linear, score=0.781, total=  35.6s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.636, total=  57.9s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.636, total=  58.8s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.636, total=  58.8s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.636, total=  58.9s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.636, total=  57.8s
# [CV] C=0.1, gamma=1, kernel=linear ...................................
# [CV] ....... C=0.1, gamma=1, kernel=linear, score=0.761, total=  36.5s
# [CV] C=0.1, gamma=1, kernel=linear ...................................
# [CV] ....... C=0.1, gamma=1, kernel=linear, score=0.748, total=  36.7s
# [CV] C=0.1, gamma=1, kernel=linear ...................................
# [CV] ....... C=0.1, gamma=1, kernel=linear, score=0.752, total=  35.3s
# [CV] C=0.1, gamma=1, kernel=linear ...................................
# [CV] ....... C=0.1, gamma=1, kernel=linear, score=0.756, total=  36.5s
# [CV] C=0.1, gamma=1, kernel=linear ...................................
# [CV] ....... C=0.1, gamma=1, kernel=linear, score=0.781, total=  36.2s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.636, total=  58.2s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.636, total=  58.4s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.636, total=  58.5s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.636, total=  57.6s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.636, total=  58.8s
# [CV] C=0.1, gamma=0.1, kernel=linear .................................
# [CV] ..... C=0.1, gamma=0.1, kernel=linear, score=0.761, total=  36.3s
# [CV] C=0.1, gamma=0.1, kernel=linear .................................
# [CV] ..... C=0.1, gamma=0.1, kernel=linear, score=0.748, total=  36.0s
# [CV] C=0.1, gamma=0.1, kernel=linear .................................
# [CV] ..... C=0.1, gamma=0.1, kernel=linear, score=0.752, total=  35.6s
# [CV] C=0.1, gamma=0.1, kernel=linear .................................
# [CV] ..... C=0.1, gamma=0.1, kernel=linear, score=0.756, total=  37.2s
# [CV] C=0.1, gamma=0.1, kernel=linear .................................
# [CV] ..... C=0.1, gamma=0.1, kernel=linear, score=0.781, total=  36.1s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.675, total=  56.4s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.659, total=  56.4s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.672, total=  57.2s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.675, total=  56.4s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.675, total=  56.7s
# [CV] C=0.1, gamma=0.01, kernel=linear ................................
# [CV] .... C=0.1, gamma=0.01, kernel=linear, score=0.761, total=  36.4s
# [CV] C=0.1, gamma=0.01, kernel=linear ................................
# [CV] .... C=0.1, gamma=0.01, kernel=linear, score=0.748, total=  36.5s
# [CV] C=0.1, gamma=0.01, kernel=linear ................................
# [CV] .... C=0.1, gamma=0.01, kernel=linear, score=0.752, total=  35.0s
# [CV] C=0.1, gamma=0.01, kernel=linear ................................
# [CV] .... C=0.1, gamma=0.01, kernel=linear, score=0.756, total=  36.5s
# [CV] C=0.1, gamma=0.01, kernel=linear ................................
# [CV] .... C=0.1, gamma=0.01, kernel=linear, score=0.781, total=  36.9s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.759, total=  42.8s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.752, total=  42.7s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.743, total=  42.0s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.757, total=  42.3s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.754, total=  41.9s
# [CV] C=0.1, gamma=0.001, kernel=linear ...............................
# [CV] ... C=0.1, gamma=0.001, kernel=linear, score=0.761, total=  35.8s
# [CV] C=0.1, gamma=0.001, kernel=linear ...............................
# [CV] ... C=0.1, gamma=0.001, kernel=linear, score=0.748, total=  35.4s
# [CV] C=0.1, gamma=0.001, kernel=linear ...............................
# [CV] ... C=0.1, gamma=0.001, kernel=linear, score=0.752, total=  35.1s
# [CV] C=0.1, gamma=0.001, kernel=linear ...............................
# [CV] ... C=0.1, gamma=0.001, kernel=linear, score=0.756, total=  36.2s
# [CV] C=0.1, gamma=0.001, kernel=linear ...............................
# [CV] ... C=0.1, gamma=0.001, kernel=linear, score=0.781, total=  36.6s
# [CV] C=0.1, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=0.1, gamma=0.0001, kernel=rbf, score=0.636, total=  45.6s
# [CV] C=0.1, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=0.1, gamma=0.0001, kernel=rbf, score=0.638, total=  46.1s
# [CV] C=0.1, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=0.1, gamma=0.0001, kernel=rbf, score=0.636, total=  46.1s
# [CV] C=0.1, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=0.1, gamma=0.0001, kernel=rbf, score=0.636, total=  46.9s
# [CV] C=0.1, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=0.1, gamma=0.0001, kernel=rbf, score=0.636, total=  45.5s
# [CV] C=0.1, gamma=0.0001, kernel=linear ..............................
# [CV] .. C=0.1, gamma=0.0001, kernel=linear, score=0.761, total=  36.8s
# [CV] C=0.1, gamma=0.0001, kernel=linear ..............................
# [CV] .. C=0.1, gamma=0.0001, kernel=linear, score=0.748, total=  36.3s
# [CV] C=0.1, gamma=0.0001, kernel=linear ..............................
# [CV] .. C=0.1, gamma=0.0001, kernel=linear, score=0.752, total=  35.5s
# [CV] C=0.1, gamma=0.0001, kernel=linear ..............................
# [CV] .. C=0.1, gamma=0.0001, kernel=linear, score=0.756, total=  36.9s
# [CV] C=0.1, gamma=0.0001, kernel=linear ..............................
# [CV] .. C=0.1, gamma=0.0001, kernel=linear, score=0.781, total=  37.1s
# [CV] C=1, gamma=2, kernel=rbf ........................................
# [CV] ............ C=1, gamma=2, kernel=rbf, score=0.641, total= 1.0min
# [CV] C=1, gamma=2, kernel=rbf ........................................
# [CV] ............ C=1, gamma=2, kernel=rbf, score=0.637, total= 1.0min
# [CV] C=1, gamma=2, kernel=rbf ........................................
# [CV] ............ C=1, gamma=2, kernel=rbf, score=0.645, total= 1.0min
# [CV] C=1, gamma=2, kernel=rbf ........................................
# [CV] ............ C=1, gamma=2, kernel=rbf, score=0.643, total= 1.0min
# [CV] C=1, gamma=2, kernel=rbf ........................................
# [CV] ............ C=1, gamma=2, kernel=rbf, score=0.642, total= 1.0min
# [CV] C=1, gamma=2, kernel=linear .....................................
# [CV] ......... C=1, gamma=2, kernel=linear, score=0.738, total=  45.5s
# [CV] C=1, gamma=2, kernel=linear .....................................
# [CV] ......... C=1, gamma=2, kernel=linear, score=0.726, total=  45.9s
# [CV] C=1, gamma=2, kernel=linear .....................................
# [CV] ......... C=1, gamma=2, kernel=linear, score=0.720, total=  45.6s
# [CV] C=1, gamma=2, kernel=linear .....................................
# [CV] ......... C=1, gamma=2, kernel=linear, score=0.728, total=  49.2s
# [CV] C=1, gamma=2, kernel=linear .....................................
# [CV] ......... C=1, gamma=2, kernel=linear, score=0.738, total=  43.6s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.641, total= 1.0min
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.637, total= 1.0min
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.645, total= 1.0min
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.643, total= 1.0min
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.642, total= 1.0min
# [CV] C=1, gamma=1, kernel=linear .....................................
# [CV] ......... C=1, gamma=1, kernel=linear, score=0.738, total=  46.1s
# [CV] C=1, gamma=1, kernel=linear .....................................
# [CV] ......... C=1, gamma=1, kernel=linear, score=0.726, total=  45.4s
# [CV] C=1, gamma=1, kernel=linear .....................................
# [CV] ......... C=1, gamma=1, kernel=linear, score=0.720, total=  45.6s
# [CV] C=1, gamma=1, kernel=linear .....................................
# [CV] ......... C=1, gamma=1, kernel=linear, score=0.728, total=  48.1s
# [CV] C=1, gamma=1, kernel=linear .....................................
# [CV] ......... C=1, gamma=1, kernel=linear, score=0.738, total=  43.5s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.641, total=  59.3s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.638, total=  59.8s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.646, total=  58.8s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.644, total=  59.2s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.641, total=  59.9s
# [CV] C=1, gamma=0.1, kernel=linear ...................................
# [CV] ....... C=1, gamma=0.1, kernel=linear, score=0.738, total=  45.7s
# [CV] C=1, gamma=0.1, kernel=linear ...................................
# [CV] ....... C=1, gamma=0.1, kernel=linear, score=0.726, total=  45.6s
# [CV] C=1, gamma=0.1, kernel=linear ...................................
# [CV] ....... C=1, gamma=0.1, kernel=linear, score=0.720, total=  45.6s
# [CV] C=1, gamma=0.1, kernel=linear ...................................
# [CV] ....... C=1, gamma=0.1, kernel=linear, score=0.728, total=  49.7s
# [CV] C=1, gamma=0.1, kernel=linear ...................................
# [CV] ....... C=1, gamma=0.1, kernel=linear, score=0.738, total=  44.0s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.754, total=  57.1s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.742, total=  57.0s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.763, total=  56.5s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.753, total=  56.5s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.756, total=  56.8s
# [CV] C=1, gamma=0.01, kernel=linear ..................................
# [CV] ...... C=1, gamma=0.01, kernel=linear, score=0.738, total=  45.7s
# [CV] C=1, gamma=0.01, kernel=linear ..................................
# [CV] ...... C=1, gamma=0.01, kernel=linear, score=0.726, total=  45.9s
# [CV] C=1, gamma=0.01, kernel=linear ..................................
# [CV] ...... C=1, gamma=0.01, kernel=linear, score=0.720, total=  45.0s
# [CV] C=1, gamma=0.01, kernel=linear ..................................
# [CV] ...... C=1, gamma=0.01, kernel=linear, score=0.728, total=  48.5s
# [CV] C=1, gamma=0.01, kernel=linear ..................................
# [CV] ...... C=1, gamma=0.01, kernel=linear, score=0.738, total=  43.3s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.791, total=  38.0s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.776, total=  36.3s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.779, total=  38.1s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.785, total=  37.8s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.795, total=  37.6s
# [CV] C=1, gamma=0.001, kernel=linear .................................
# [CV] ..... C=1, gamma=0.001, kernel=linear, score=0.738, total=  45.6s
# [CV] C=1, gamma=0.001, kernel=linear .................................
# [CV] ..... C=1, gamma=0.001, kernel=linear, score=0.726, total=  45.9s
# [CV] C=1, gamma=0.001, kernel=linear .................................
# [CV] ..... C=1, gamma=0.001, kernel=linear, score=0.720, total=  46.5s
# [CV] C=1, gamma=0.001, kernel=linear .................................
# [CV] ..... C=1, gamma=0.001, kernel=linear, score=0.728, total=  48.2s
# [CV] C=1, gamma=0.001, kernel=linear .................................
# [CV] ..... C=1, gamma=0.001, kernel=linear, score=0.738, total=  42.9s
# [CV] C=1, gamma=0.0001, kernel=rbf ...................................
# [CV] ....... C=1, gamma=0.0001, kernel=rbf, score=0.762, total=  40.4s
# [CV] C=1, gamma=0.0001, kernel=rbf ...................................
# [CV] ....... C=1, gamma=0.0001, kernel=rbf, score=0.759, total=  40.3s
# [CV] C=1, gamma=0.0001, kernel=rbf ...................................
# [CV] ....... C=1, gamma=0.0001, kernel=rbf, score=0.750, total=  39.7s
# [CV] C=1, gamma=0.0001, kernel=rbf ...................................
# [CV] ....... C=1, gamma=0.0001, kernel=rbf, score=0.759, total=  40.2s
# [CV] C=1, gamma=0.0001, kernel=rbf ...................................
# [CV] ....... C=1, gamma=0.0001, kernel=rbf, score=0.762, total=  40.8s
# [CV] C=1, gamma=0.0001, kernel=linear ................................
# [CV] .... C=1, gamma=0.0001, kernel=linear, score=0.738, total=  45.5s
# [CV] C=1, gamma=0.0001, kernel=linear ................................
# [CV] .... C=1, gamma=0.0001, kernel=linear, score=0.726, total=  45.6s
# [CV] C=1, gamma=0.0001, kernel=linear ................................
# [CV] .... C=1, gamma=0.0001, kernel=linear, score=0.720, total=  45.1s
# [CV] C=1, gamma=0.0001, kernel=linear ................................
# [CV] .... C=1, gamma=0.0001, kernel=linear, score=0.728, total=  48.7s
# [CV] C=1, gamma=0.0001, kernel=linear ................................
# [CV] .... C=1, gamma=0.0001, kernel=linear, score=0.738, total=  44.5s
# [CV] C=10, gamma=2, kernel=rbf .......................................
# [CV] ........... C=10, gamma=2, kernel=rbf, score=0.641, total=  59.5s
# [CV] C=10, gamma=2, kernel=rbf .......................................
# [CV] ........... C=10, gamma=2, kernel=rbf, score=0.637, total=  59.8s
# [CV] C=10, gamma=2, kernel=rbf .......................................
# [CV] ........... C=10, gamma=2, kernel=rbf, score=0.645, total=  59.9s
# [CV] C=10, gamma=2, kernel=rbf .......................................
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-f79d04876a76> in <module>()
#       9
#      10 # fitting the model for grid search
# ---> 11 svm_grid.fit(X_train, y_train)
#      12
#      13 # print how our model looks after hyper-parameter tuning
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     708                 return results
#     709
# --> 710             self._run_search(evaluate_candidates)
#     711
#     712         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1149     def _run_search(self, evaluate_candidates):
#    1150         """Search all candidates in param_grid"""
# -> 1151         evaluate_candidates(ParameterGrid(self.param_grid))
#    1152
#    1153
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     687                                for parameters, (train, test)
#     688                                in product(candidate_params,
# --> 689                                           cv.split(X, y, groups)))
#     690
#     691                 if len(out) < 1:
#
# /usr/local/lib/python3.7/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1044                 self._iterating = self._original_iterator is not None
#    1045
# -> 1046             while self.dispatch_one_batch(iterator):
#    1047                 pass
#    1048
#
# /usr/local/lib/python3.7/dist-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     859                 return False
#     860             else:
# --> 861                 self._dispatch(tasks)
#     862                 return True
#     863
#
# /usr/local/lib/python3.7/dist-packages/joblib/parallel.py in _dispatch(self, batch)
#     777         with self._lock:
#     778             job_idx = len(self._jobs)
# --> 779             job = self._backend.apply_async(batch, callback=cb)
#     780             # A job can complete so quickly than its callback is
#     781             # called before we get here, causing self._jobs to
#
# /usr/local/lib/python3.7/dist-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# /usr/local/lib/python3.7/dist-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# /usr/local/lib/python3.7/dist-packages/joblib/parallel.py in __call__(self)
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     262             return [func(*args, **kwargs)
# --> 263                     for func, args, kwargs in self.items]
#     264
#     265     def __reduce__(self):
#
# /usr/local/lib/python3.7/dist-packages/joblib/parallel.py in <listcomp>(.0)
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     262             return [func(*args, **kwargs)
# --> 263                     for func, args, kwargs in self.items]
#     264
#     265     def __reduce__(self):
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     542     else:
#     543         fit_time = time.time() - start_time
# --> 544         test_scores = _score(estimator, X_test, y_test, scorer)
#     545         score_time = time.time() - start_time - fit_time
#     546         if return_train_score:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py in _score(estimator, X_test, y_test, scorer)
#     589         scores = scorer(estimator, X_test)
#     590     else:
# --> 591         scores = scorer(estimator, X_test, y_test)
#     592
#     593     error_msg = ("scoring must return a number, got %s (%s) "
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_scorer.py in __call__(self, estimator, *args, **kwargs)
#      87                                       *args, **kwargs)
#      88             else:
# ---> 89                 score = scorer(estimator, *args, **kwargs)
#      90             scores[name] = score
#      91         return scores
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_scorer.py in _passthrough_scorer(estimator, *args, **kwargs)
#     369 def _passthrough_scorer(estimator, *args, **kwargs):
#     370     """Function that wraps estimator.score"""
# --> 371     return estimator.score(*args, **kwargs)
#     372
#     373
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in score(self, X, y, sample_weight)
#     367         """
#     368         from .metrics import accuracy_score
# --> 369         return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#     370
#     371
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py in predict(self, X)
#     592             y = np.argmax(self.decision_function(X), axis=1)
#     593         else:
# --> 594             y = super().predict(X)
#     595         return self.classes_.take(np.asarray(y, dtype=np.intp))
#     596
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py in predict(self, X)
#     315         X = self._validate_for_predict(X)
#     316         predict = self._sparse_predict if self._sparse else self._dense_predict
# --> 317         return predict(X)
#     318
#     319     def _dense_predict(self, X):
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py in _dense_predict(self, X)
#     337             self.probA_, self.probB_, svm_type=svm_type, kernel=kernel,
#     338             degree=self.degree, coef0=self.coef0, gamma=self._gamma,
# --> 339             cache_size=self.cache_size)
#     340
#     341     def _sparse_predict(self, X):
#
# KeyboardInterrupt:

# %%
#Fine-tuned Model
# C=1, gamma=0.001, kernel=rbf, score=0.795, total=  37.6s
from sklearn.svm import SVC
svm = SVC(kernel='rbf', C=1, gamma=0.001)

svm.fit(X_train, y_train)
# Out:
# SVC(C=1, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=0.001, kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
#Evaluation of the fine-tuned model
from sklearn.metrics import classification_report

#predict response using SVM
svm_y_pred = svm.predict(X_test)

# calculate report for svm model
svm_report = classification_report(y_test, svm_y_pred, target_names=['not flooded', 'flooded'])

print('SVM Model classification report is: \n', svm_report)
# Out:
# SVM Model classification report is:
#                precision    recall  f1-score   support
#
#  not flooded       0.79      0.91      0.84       839
#      flooded       0.78      0.57      0.66       480
#
#     accuracy                           0.79      1319
#    macro avg       0.78      0.74      0.75      1319
# weighted avg       0.79      0.79      0.78      1319
